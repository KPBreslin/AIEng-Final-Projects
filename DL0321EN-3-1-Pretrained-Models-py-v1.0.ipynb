# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Pre-Trained Models</font></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you will learn how to leverage pre-trained models to build image classifiers instead of building a model from scratch.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Import Libraries and Packages</a>
# 2. <a href="#item32">Download Data</a>
# 3. <a href="#item33">Define Global Constants</a>
# 4. <a href="#item34">Construct ImageDataGenerator Instances</a>
# 5. <a href="#item35">Compile and Fit Model</a>
#
# </font>
#
# </div>

# %% [markdown]
# <a id='item31'></a>

# %% [markdown]
# ## Import Libraries and Packages

# %% [markdown]
# Let's start the lab by importing the libraries that we will be using in this lab.

# %% [markdown]
# First, we will import the ImageDataGenerator module since we will be leveraging it to train our model in batches.

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# In this lab, we will be using the Keras library to build an image classifier, so let's download the Keras library.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Finally, we will be leveraging the ResNet50 model to build our classifier, so let's download it as well.

# %%
from keras.applications import ResNet50
from keras.applications.resnet50 import preprocess_input

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Download Data

# %% [markdown]
# For your convenience, I have placed the data on a server which you can retrieve easily using the **wget** command. So let's run the following line of code to get the data. Given the large size of the image dataset, it might take some time depending on your internet speed.

# %%
## get the data
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week3.zip
# Out:
# --2020-05-01 14:34:11--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week3.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261482368 (249M) [application/zip]
# Saving to: ‘concrete_data_week3.zip’
#
# concrete_data_week3 100%[===================>] 249.37M  24.1MB/s    in 11s
#
# 2020-05-01 14:34:22 (23.2 MB/s) - ‘concrete_data_week3.zip’ saved [261482368/261482368]

# %% [markdown]
# And now if you check the left directory pane, you should see the zipped file *concrete_data_week3.zip* appear. So, let's go ahead and unzip the file to access the images. Given the large number of images in the dataset, this might take a couple of minutes, so please be patient, and wait until the code finishes running.

# %%
# !unzip concrete_data_week3.zip
# Out:
# Archive:  concrete_data_week3.zip
#    creating: concrete_data_week3/
#    creating: concrete_data_week3/valid/
#    creating: concrete_data_week3/valid/positive/
#   inflating: concrete_data_week3/valid/positive/16679_1.jpg
#    creating: __MACOSX/concrete_data_week3/
#    creating: __MACOSX/concrete_data_week3/valid/
#    creating: __MACOSX/concrete_data_week3/valid/positive/
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._16679_1.jpg
#   inflating: concrete_data_week3/valid/positive/19463.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._19463.jpg
#   inflating: concrete_data_week3/valid/positive/19041_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._19041_1.jpg
#   inflating: concrete_data_week3/valid/positive/19004_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._19004_1.jpg
#   inflating: concrete_data_week3/valid/positive/18041_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18041_1.jpg
#   inflating: concrete_data_week3/valid/positive/18802_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18802_1.jpg
#   inflating: concrete_data_week3/valid/positive/17679_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._17679_1.jpg
#   inflating: concrete_data_week3/valid/positive/18490_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18490_1.jpg
#   inflating: concrete_data_week3/valid/positive/19477.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._19477.jpg
#   inflating: concrete_data_week3/valid/positive/18004_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18004_1.jpg
#   inflating: concrete_data_week3/valid/positive/18847_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18847_1.jpg
#   inflating: concrete_data_week3/valid/positive/17111_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._17111_1.jpg
#   inflating: concrete_data_week3/valid/positive/15267_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._15267_1.jpg
#   inflating: concrete_data_week3/valid/positive/17952_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._17952_1.jpg
#   inflating: concrete_data_week3/valid/positive/18729_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18729_1.jpg
#   inflating: concrete_data_week3/valid/positive/17154_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._17154_1.jpg
#   inflating: concrete_data_week3/valid/positive/17917_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._17917_1.jpg
#   inflating: concrete_data_week3/valid/positive/15222_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._
1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._16172_1.jpg
#   inflating: concrete_data_week3/valid/positive/16931_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._16931_1.jpg
#   inflating: concrete_data_week3/valid/positive/19366_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._19366_1.jpg
#   inflating: concrete_data_week3/valid/positive/16989_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._16989_1.jpg
#   inflating: concrete_data_week3/valid/positive/19323_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._19323_1.jpg
#   inflating: concrete_data_week3/valid/positive/15628_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._15628_1.jpg
#   inflating: concrete_data_week3/valid/positive/18366_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._18366_1.jpg
#   inflating: concrete_data_week3/valid/positive/17989_1.jpg
#   inflating: __MACOSX/concrete_data_week3/valid/positive/._17989_1.jpg
# ...
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09969.jpg
#   inflating: concrete_data_week3/train/positive/07944.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07944.jpg
#   inflating: concrete_data_week3/train/positive/06482.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06482.jpg
#   inflating: concrete_data_week3/train/positive/10277_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10277_1.jpg
#   inflating: concrete_data_week3/train/positive/12942_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12942_1.jpg
#   inflating: concrete_data_week3/train/positive/00795.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00795.jpg
#   inflating: concrete_data_week3/train/positive/12101_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12101_1.jpg
#   inflating: concrete_data_week3/train/positive/05835.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05835.jpg
#   inflating: concrete_data_week3/train/positive/02182.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02182.jpg
#   inflating: concrete_data_week3/train/positive/05821.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05821.jpg
#   inflating: concrete_data_week3/train/positive/13595_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13595_1.jpg
#   inflating: concrete_data_week3/train/positive/03288.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03288.jpg
#   inflating: concrete_data_week3/train/positive/14085_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14085_1.jpg
#   inflating: concrete_data_week3/train/positive/02196.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02196.jpg
#   inflating: concrete_data_week3/train/positive/00959.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00959.jpg
#   inflating: concrete_data_week3/train/positive/11232_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11232_1.jpg
#   inflating: concrete_data_week3/train/positive/14454_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14454_1.jpg
#   inflating: concrete_data_week3/train/positive/13907_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13907_1.jpg
#   inflating: concrete_data_week3/train/positive/00781.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00781.jpg
#   inflating: concrete_data_week3/train/positive/13144_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13144_1.jpg
#   inflating: concrete_data_week3/train/positive/14883_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14883_1.jpg
#   inflating: concrete_data_week3/train/positive/07788.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07788.jpg
#   inflating: concrete_data_week3/train/positive/07950.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07950.jpg
#   inflating: concrete_data_week3/train/positive/06496.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06496.jpg
#   inflating: concrete_data_week3/train/positive/13942_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13942_1.jpg
#   inflating: concrete_data_week3/train/positive/14411_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14411_1.jpg
#   inflating: concrete_data_week3/train/positive/11277_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11277_1.jpg
#   inflating: concrete_data_week3/train/positive/13101_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13101_1.jpg
#   inflating: concrete_data_week3/train/positive/04281.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04281.jpg
#   inflating: concrete_data_week3/train/positive/02828.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02828.jpg
#   inflating: concrete_data_week3/train/positive/03505.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03505.jpg
#   inflating: concrete_data_week3/train/positive/05174.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05174.jpg
#   inflating: concrete_data_week3/train/positive/01312.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._01312.jpg
#   inflating: concrete_data_week3/train/positive/07763.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07763.jpg
#   inflating: concrete_data_week3/train/positive/08450.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08450.jpg
#   inflating: concrete_data_week3/train/positive/09996.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09996.jpg
#   inflating: concrete_data_week3/train/positive/07005.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07005.jpg
#   inflating: concrete_data_week3/train/positive/08336.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08336.jpg
#   inflating: concrete_data_week3/train/positive/09028.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09028.jpg
#   inflating: concrete_data_week3/train/positive/01474.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._01474.jpg
#   inflating: concrete_data_week3/train/positive/05612.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05612.jpg
#   inflating: concrete_data_week3/train/positive/13568_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13568_1.jpg
#   inflating: concrete_data_week3/train/positive/14078_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14078_1.jpg
#   inflating: concrete_data_week3/train/positive/03263.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03263.jpg
#   inflating: concrete_data_week3/train/positive/02169.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02169.jpg
#   inflating: concrete_data_week3/train/positive/05606.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05606.jpg
#   inflating: concrete_data_week3/train/positive/04518.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04518.jpg
#   inflating: concrete_data_week3/train/positive/03277.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03277.jpg
#   inflating: concrete_data_week3/train/positive/07011.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07011.jpg
#   inflating: concrete_data_week3/train/positive/08322.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08322.jpg
#   inflating: concrete_data_week3/train/positive/01460.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._01460.jpg
#   inflating: concrete_data_week3/train/positive/01306.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._01306.jpg
#   inflating: concrete_data_week3/train/positive/12568_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12568_1.jpg
#   inflating: concrete_data_week3/train/positive/06469.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06469.jpg
#   inflating: concrete_data_week3/train/positive/07777.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07777.jpg
#   inflating: concrete_data_week3/train/positive/08444.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08444.jpg
#   inflating: concrete_data_week3/train/positive/09982.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09982.jpg
#   inflating: concrete_data_week3/train/positive/00018.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00018.jpg
#   inflating: concrete_data_week3/train/positive/03511.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03511.jpg
#   inflating: concrete_data_week3/train/positive/05160.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05160.jpg
#   inflating: concrete_data_week3/train/positive/07987.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07987.jpg
#   inflating: concrete_data_week3/train/positive/09772.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09772.jpg
#   inflating: concrete_data_week3/train/positive/06441.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06441.jpg
#   inflating: concrete_data_week3/train/positive/00030.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00030.jpg
#   inflating: concrete_data_week3/train/positive/12694_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12694_1.jpg
#   inflating: concrete_data_week3/train/positive/03539.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03539.jpg
#   inflating: concrete_data_week3/train/positive/04256.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04256.jpg
#   inflating: concrete_data_week3/train/positive/10970_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10970_1.jpg
#   inflating: concrete_data_week3/train/positive/12245_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12245_1.jpg
#   inflating: concrete_data_week3/train/positive/10133_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10133_1.jpg
#   inflating: concrete_data_week3/train/positive/05148.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._05148.jpg
#   inflating: concrete_data_week3/train/positive/02627.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02627.jpg
#   inflating: concrete_data_week3/train/positive/02141.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02141.jpg
#   inflating: concrete_data_week3/train/positive/04530.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04530.jpg
#   inflating: concrete_data_week3/train/positive/00756.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00756.jpg
#   inflating: concrete_data_week3/train/positive/12200_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12200_1.jpg
#   inflating: concrete_data_week3/train/positive/10935_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10935_1.jpg
#   inflating: concrete_data_week3/train/positive/07039.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07039.jpg
#   inflating: concrete_data_week3/train/positive/09014.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09014.jpg
#   inflating: concrete_data_week3/train/positive/06327.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06327.jpg
#   inflating: concrete_data_week3/train/positive/01448.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._01448.jpg
#   inflating: concrete_data_week3/train/positive/10176_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10176_1.jpg
#   inflating: concrete_data_week3/train/positive/00742.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00742.jpg
#   inflating: concrete_data_week3/train/positive/13245_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13245_1.jpg
#   inflating: concrete_data_week3/train/positive/11970_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11970_1.jpg
#   inflating: concrete_data_week3/train/positive/09000.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09000.jpg
#   inflating: concrete_data_week3/train/positive/06333.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06333.jpg
#   inflating: concrete_data_week3/train/positive/11133_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11133_1.jpg
#   inflating: concrete_data_week3/train/positive/14755_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14755_1.jpg
#   inflating: concrete_data_week3/train/positive/02155.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02155.jpg
#   inflating: concrete_data_week3/train/positive/14384_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14384_1.jpg
#   inflating: concrete_data_week3/train/positive/04524.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04524.jpg
#   inflating: concrete_data_week3/train/positive/13694_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13694_1.jpg
#   inflating: concrete_data_week3/train/positive/04242.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04242.jpg
#   inflating: concrete_data_week3/train/positive/11935_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11935_1.jpg
#   inflating: concrete_data_week3/train/positive/13200_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13200_1.jpg
#   inflating: concrete_data_week3/train/positive/14710_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14710_1.jpg
#   inflating: concrete_data_week3/train/positive/11176_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11176_1.jpg
#   inflating: concrete_data_week3/train/positive/02633.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._02633.jpg
#   inflating: concrete_data_week3/train/positive/07993.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._07993.jpg
#   inflating: concrete_data_week3/train/positive/09766.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._09766.jpg
#   inflating: concrete_data_week3/train/positive/06455.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06455.jpg
#   inflating: concrete_data_week3/train/positive/08478.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08478.jpg
#   inflating: concrete_data_week3/train/positive/00024.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._00024.jpg
#   inflating: concrete_data_week3/train/positive/10397_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10397_1.jpg
#   inflating: concrete_data_week3/train/positive/12430_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12430_1.jpg
#   inflating: concrete_data_week3/train/positive/04915.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._04915.jpg
#   inflating: concrete_data_week3/train/positive/10746_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10746_1.jpg
#   inflating: concrete_data_week3/train/positive/12475_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._12475_1.jpg
#   inflating: concrete_data_week3/train/positive/08849.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08849.jpg
#   inflating: concrete_data_week3/train/positive/10703_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._10703_1.jpg
#   inflating: concrete_data_week3/train/positive/06864.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06864.jpg
#   inflating: concrete_data_week3/train/positive/08691.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08691.jpg
#   inflating: concrete_data_week3/train/positive/14963_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14963_1.jpg
#   inflating: concrete_data_week3/train/positive/13430_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._13430_1.jpg
#   inflating: concrete_data_week3/train/positive/14120_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._14120_1.jpg
#   inflating: concrete_data_week3/train/positive/11746_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11746_1.jpg
#   inflating: concrete_data_week3/train/positive/06870.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._06870.jpg
#   inflating: concrete_data_week3/train/positive/08685.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._08685.jpg
#   inflating: concrete_data_week3/train/positive/11397_1.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._11397_1.jpg
#   inflating: concrete_data_week3/train/positive/03908.jpg
#   inflating: __MACOSX/concrete_data_week3/train/positive/._03908.jpg

# %% [markdown]
# Now, you should see the folder *concrete_data_week3* appear in the left pane. If you open this folder by double-clicking on it, you will find that it contains two folders: *train* and *valid*. And if you explore these folders, you will find that each contains two subfolders: *positive* and *negative*. These are the same folders that we saw in the labs in the previous modules of this course, where *negative* is the negative class and it represents the concrete images with no cracks and *positive* is the positive class and it represents the concrete images with cracks.

# %% [markdown]
# **Important Note**: There are thousands and thousands of images in each folder, so please don't attempt to double click on the *negative* and *positive* folders. This may consume all of your memory and you may end up with a **50*** error. So please **DO NOT DO IT**.

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Define Global Constants

# %% [markdown]
# Here, we will define constants that we will be using throughout the rest of the lab.
#
# 1. We are obviously dealing with two classes, so *num_classes* is 2.
# 2. The ResNet50 model was built and trained using images of size (224 x 224). Therefore, we will have to resize our images from (227 x 227) to (224 x 224).
# 3. We will training and validating the model using batches of 100 images.

# %%
num_classes = 2

image_resize = 224

batch_size_training = 100
batch_size_validation = 100

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Construct ImageDataGenerator Instances

# %% [markdown]
# In order to instantiate an ImageDataGenerator instance, we will set the **preprocessing_function** argument to *preprocess_input* which we imported from **keras.applications.resnet50** in order to preprocess our images the same way the images used to train ResNet50 model were processed.

# %%
data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %% [markdown]
# Next, we will use the *flow_from_directory* method to get the training images as follows:

# %%
train_generator = data_generator.flow_from_directory(
    'concrete_data_week3/train',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_training,
    class_mode='categorical')

# %% [markdown]
# **Your Turn**: Use the *flow_from_directory* method to get the validation images and assign the result to **validation_generator**.

# %%
## Type your answer here

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- The correct answer is:
# validation_generator = data_generator.flow_from_directory(
#     'concrete_data_week3/valid',
#     target_size=(image_resize, image_resize),
#     batch_size=batch_size_validation,
#     class_mode='categorical')
# -->

# %% [markdown]
# <a id='item35'></a>

# %% [markdown]
# ## Build, Compile and Fit Model

# %% [markdown]
# In this section, we will start building our model. We will use the Sequential model class from Keras.

# %%
model = Sequential()

# %% [markdown]
# Next, we will add the ResNet50 pre-trained model to out model. However, note that we don't want to include the top layer or the output layer of the pre-trained model. We actually want to define our own output layer and train it so that it is optimized for our image dataset. In order to leave out the output layer of the pre-trained model, we will use the argument *include_top* and set it to **False**.

# %%
model.add(ResNet50(
    include_top=False,
    pooling='avg',
    weights='imagenet',
    ))

# %% [markdown]
# Then, we will define our output layer as a **Dense** layer, that consists of two nodes and uses the **Softmax** function as the activation function.

# %%
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# You can access the model's layers using the *layers* attribute of our model object.

# %%
model.layers

# %% [markdown]
# You can see that our model is composed of two sets of layers. The first set is the layers pertaining to ResNet50 and the second set is a single layer, which is our Dense layer that we defined above.

# %% [markdown]
# You can access the ResNet50 layers by running the following:

# %%
model.layers[0].layers

# %% [markdown]
# Since the ResNet50 model has already been trained, then we want to tell our model not to bother with training the ResNet part, but to train only our dense output layer. To do that, we run the following.

# %%
model.layers[0].trainable = False

# %% [markdown]
# And now using the *summary* attribute of the model, we can see how many parameters we will need to optimize in order to train the output layer.

# %%
model.summary()

# %% [markdown]
# Next we compile our model using the **adam** optimizer.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Before we are able to start the training process, with an ImageDataGenerator, we will need to define how many steps compose an epoch. Typically, that is the number of images divided by the batch size. Therefore, we define our steps per epoch as follows:

# %%
steps_per_epoch_training = len(train_generator)
steps_per_epoch_validation = len(validation_generator)
num_epochs = 2

# %% [markdown]
# Finally, we are ready to start training our model. Unlike a conventional deep learning training were data is not streamed from a directory, with an ImageDataGenerator where data is augmented in batches, we use the **fit_generator** method.

# %%
fit_history = model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch_training,
    epochs=num_epochs,
    validation_data=validation_generator,
    validation_steps=steps_per_epoch_validation,
    verbose=1,
)

# %% [markdown]
# Now that the model is trained, you are ready to start using it to classify images.

# %% [markdown]
# Since training can take a long time when building deep learning models, it is always a good idea to save your model once the training is complete if you believe you will be using the model again later. You will be using this model in the next module, so go ahead and save your model.

# %%
model.save('classifier_resnet_model.h5')

# %% [markdown]
# Now, you should see the model file *classifier_resnet_model.h5* apprear in the left directory pane.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by Alex Aklson. I hope you found this lab interesting and educational.

# %% [markdown]
# This notebook is part of a course on **Coursera** called *AI Capstone Project with Deep Learning*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0321EN_Coursera_Week3_LAB1).

# %% [markdown]
# <hr>
#
# Copyright &copy; 2020 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
